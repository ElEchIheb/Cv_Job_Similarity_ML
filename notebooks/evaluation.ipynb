# %% [markdown]
# # Evaluation du systeme hybride
#
# Ce notebook lance le pipeline d'evaluation complet sur le dataset synthetique.

# %%
from src.evaluation.evaluator import EvaluationSuite

suite = EvaluationSuite()
results = suite.run_full_evaluation('data/datasets/cv_job_dataset.csv')
results['analysis']['split_sizes']
